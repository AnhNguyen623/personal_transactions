# %%
# !pip3 install langchain_community
# Out:
# Collecting langchain_community
#   Using cached langchain_community-0.3.29-py3-none-any.whl.metadata (2.9 kB)
# Collecting langchain-core<2.0.0,>=0.3.75 (from langchain_community)
#   Using cached langchain_core-0.3.75-py3-none-any.whl.metadata (5.7 kB)
# Collecting langchain<2.0.0,>=0.3.27 (from langchain_community)
#   Using cached langchain-0.3.27-py3-none-any.whl.metadata (7.8 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain_community)
#   Using cached sqlalchemy-2.0.43-cp313-cp313-macosx_11_0_arm64.whl.metadata (9.6 kB)
# Requirement already satisfied: requests<3,>=2.32.5 in ./venv/lib/python3.13/site-packages (from langchain_community) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in ./venv/lib/python3.13/site-packages (from langchain_community) (6.0.2)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain_community)
#   Using cached aiohttp-3.12.15-cp313-cp313-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Collecting tenacity!=8.4.0,<10,>=8.1.0 (from langchain_community)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting dataclasses-json<0.7,>=0.6.7 (from langchain_community)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain_community)
#   Using cached pydantic_settings-2.10.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting langsmith>=0.1.125 (from langchain_community)
#   Using cached langsmith-0.4.27-py3-none-any.whl.metadata (14 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain_community)
#   Using cached httpx_sse-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: numpy>=2.1.0 in ./venv/lib/python3.13/site-packages (from langchain_community) (2.3.2)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in ./venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.3.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached frozenlist-1.7.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (18 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached multidict-6.6.4-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached propcache-0.3.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached yarl-1.20.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (73 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.6.7->langchain_community)
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.6.7->langchain_community)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.9 (from langchain<2.0.0,>=0.3.27->langchain_community)
#   Using cached langchain_text_splitters-0.3.11-py3-none-any.whl.metadata (1.8 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain<2.0.0,>=0.3.27->langchain_community)
#   Using cached pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<2.0.0,>=0.3.75->langchain_community)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: typing-extensions>=4.7 in ./venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain_community) (4.15.0)
# Requirement already satisfied: packaging>=23.2 in ./venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain_community) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./venv/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<2.0.0,>=0.3.75->langchain_community) (3.0.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain_community)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain_community)
#   Using cached pydantic_core-2.33.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain_community)
#   Using cached typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.10.1->langchain_community)
#   Using cached python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.13/site-packages (from requests<3,>=2.32.5->langchain_community) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.13/site-packages (from requests<3,>=2.32.5->langchain_community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.13/site-packages (from requests<3,>=2.32.5->langchain_community) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.13/site-packages (from requests<3,>=2.32.5->langchain_community) (2025.8.3)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.6.7->langchain_community)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./venv/lib/python3.13/site-packages (from langsmith>=0.1.125->langchain_community) (0.28.1)
# Collecting orjson>=3.9.14 (from langsmith>=0.1.125->langchain_community)
#   Using cached orjson-3.11.3-cp313-cp313-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (41 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith>=0.1.125->langchain_community)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard>=0.23.0 (from langsmith>=0.1.125->langchain_community)
#   Using cached zstandard-0.24.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (3.1 kB)
# Requirement already satisfied: anyio in ./venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community) (4.10.0)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in ./venv/lib/python3.13/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community) (1.3.1)
# Using cached langchain_community-0.3.29-py3-none-any.whl (2.5 MB)
# Using cached aiohttp-3.12.15-cp313-cp313-macosx_11_0_arm64.whl (466 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached httpx_sse-0.4.1-py3-none-any.whl (8.1 kB)
# Using cached langchain-0.3.27-py3-none-any.whl (1.0 MB)
# Using cached langchain_core-0.3.75-py3-none-any.whl (443 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langchain_text_splitters-0.3.11-py3-none-any.whl (33 kB)
# Using cached marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Using cached multidict-6.6.4-cp313-cp313-macosx_11_0_arm64.whl (43 kB)
# Using cached pydantic-2.11.7-py3-none-any.whl (444 kB)
# Using cached pydantic_core-2.33.2-cp313-cp313-macosx_11_0_arm64.whl (1.8 MB)
# Using cached pydantic_settings-2.10.1-py3-none-any.whl (45 kB)
# Using cached sqlalchemy-2.0.43-cp313-cp313-macosx_11_0_arm64.whl (2.1 MB)
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached yarl-1.20.1-cp313-cp313-macosx_11_0_arm64.whl (88 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached frozenlist-1.7.0-cp313-cp313-macosx_11_0_arm64.whl (45 kB)
# Using cached langsmith-0.4.27-py3-none-any.whl (384 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Using cached orjson-3.11.3-cp313-cp313-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (238 kB)
# Using cached propcache-0.3.2-cp313-cp313-macosx_11_0_arm64.whl (41 kB)
# Using cached python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Using cached zstandard-0.24.0-cp313-cp313-macosx_11_0_arm64.whl (640 kB)
# Installing collected packages: zstandard, typing-inspection, tenacity, SQLAlchemy, python-dotenv, pydantic-core, propcache, orjson, mypy-extensions, multidict, marshmallow, jsonpatch, httpx-sse, frozenlist, annotated-types, aiohappyeyeballs, yarl, typing-inspect, requests-toolbelt, pydantic, aiosignal, pydantic-settings, langsmith, dataclasses-json, aiohttp, langchain-core, langchain-text-splitters, langchain, langchain_community
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29/29 [langchain_community]ngchain_community]
# Successfully installed SQLAlchemy-2.0.43 aiohappyeyeballs-2.6.1 aiohttp-3.12.15 aiosignal-1.4.0 annotated-types-0.7.0 dataclasses-json-0.6.7 frozenlist-1.7.0 httpx-sse-0.4.1 jsonpatch-1.33 langchain-0.3.27 langchain-core-0.3.75 langchain-text-splitters-0.3.11 langchain_community-0.3.29 langsmith-0.4.27 marshmallow-3.26.1 multidict-6.6.4 mypy-extensions-1.1.0 orjson-3.11.3 propcache-0.3.2 pydantic-2.11.7 pydantic-core-2.33.2 pydantic-settings-2.10.1 python-dotenv-1.1.1 requests-toolbelt-1.0.0 tenacity-9.1.2 typing-inspect-0.9.0 typing-inspection-0.4.1 yarl-1.20.1 zstandard-0.24.0

# %%
from langchain_community.llms import Ollama

# %%
llm = Ollama(model="llama2")
llm.invoke("The first man on the moon was ...")
# Out:
# /var/folders/gq/nm3rwg7105xb8h323rbv8qfr0000gn/T/ipykernel_39092/3421170792.py:1: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaLLM``.
#   llm = Ollama(model="llama2")
# '\nThe first man on the moon was Neil Armstrong. He stepped foot on the lunar surface on July 20, 1969, during the Apollo 11 mission. Armstrong famously declared, "That\'s one small step for man, one giant leap for mankind," as he became the first person to walk on the moon.'

# %%
llm.invoke("Can you add an appropriate category next to each of the following expenses. Respond with a list of categories separated by commas. For example, Spotify AB by Adyen - \
Entertainment, Beta Boulders Ams Amsterdam Nld - Sports, etc.: \
ISS Catering Services De Meern, Vishandel Sier AMSTELVEEN, Ministerie van Justitie en Veiligheid, Etos AMSTERDAM NLD, Bistro Bar Amsterdam")
# Out:
# '\nOf course! Here are the categories for each of the expenses you provided:\n\nSpotify AB by Adyen - Entertainment\nBeta Boulders Ams Amsterdam Nld - Sports\nISS Catering Services De Meern - Food and Beverage\nVishandel Sier AMSTELVEEN - Food and Beverage\nMinisterie van Justitie en Veiligheid - Government\nEtos AMSTERDAM NLD - Retail\nBistro Bar Amsterdam - Food and Beverage'

# %% [markdown]
# # Read Transaction Data

# %%
# Read the transactions_2023_2024.csv file 
import pandas as pd
df = pd.read_csv("transactions_2023_2024.csv")
df
# Out:
#            Date                  Name / Description Expense/Income  \
# 0    2023-01-05                                Rent        Expense
# 1    2023-01-05                   Electricity (EVN)        Expense
# 2    2023-01-05                               Water        Expense
# 3    2023-01-05                  Internet (Viettel)        Expense
# 4    2023-01-05                          Phone bill        Expense
# ..          ...                                 ...            ...
# 322  2024-12-01                      Monthly Salary         Income
# 323  2024-12-20           Shopping (Shopee/Clothes)        Expense
# 324  2024-12-16  Food & Drinks (restaurants, cafes)        Expense
# 325  2024-12-13           Shopping (Shopee/Clothes)        Expense
# 326  2024-12-27           Shopping (Shopee/Clothes)        Expense
#
#     Amount (VND)
# 0      6,000,000
# 1        500,000
# 2        200,000
# 3        250,000
# 4        150,000
# ..           ...
# 322   21,765,767
# 323      215,527
# 324      204,343
# 325      288,558
# 326      975,839
#
# [327 rows x 4 columns]

# %%
# Get unique transactions in the Name / Description column
unique_transactions = df["Name / Description"].unique()
len(unique_transactions)
# Out:
# 18

# %%
unique_transactions[1:10]
# Out:
# array(['Electricity (EVN)', 'Water', 'Internet (Viettel)', 'Phone bill',
#        'Spotify Premium', 'Netflix', 'Gym membership', 'English course',
#        'Monthly Salary'], dtype=object)

# %% [markdown]
# # Categorise Bank Transaction With Llama2

# %%
# Get index list
def hop(start, stop, step):
    for i in range(start, stop, step):
        yield i
    yield stop

index_list = list(hop(0, len(unique_transactions), 30))
index_list
# Out:
# [0, 18]

# %%
def categorize_transactions(transaction_names, llm):
    response = llm.invoke("Can you add an appropriate category to the following expenses. For example: Rent - Housing , Netflix - Entertainment, etc.. Categories should be less than 4 words. " + transaction_names)
    response = response.split('\n')

    print(response)

    # Put in dataframe
    categories_df = pd.DataFrame({'Transaction vs category': response})
    categories_df[['Transaction', 'Category']] = categories_df['Transaction vs category'].str.split(' - ', expand=True)
    
    return categories_df

# %%
# Test out the function
categorize_transactions('Rent, Phone bill, Water, Monthly Salary',
                        llm)
# Out:
# ['', 'Of course! Here are the categories for the expenses you provided:', '', '* Rent - Housing', '* Phone bill - Utilities', '* Water - Utilities', '* Monthly Salary - Income']
#                              Transaction vs category  \
# 0
# 1  Of course! Here are the categories for the exp...
# 2
# 3                                   * Rent - Housing
# 4                           * Phone bill - Utilities
# 5                                * Water - Utilities
# 6                          * Monthly Salary - Income
#
#                                          Transaction   Category
# 0                                                          None
# 1  Of course! Here are the categories for the exp...       None
# 2                                                          None
# 3                                             * Rent    Housing
# 4                                       * Phone bill  Utilities
# 5                                            * Water  Utilities
# 6                                   * Monthly Salary     Income

# %%
# Intialise the categories_df_all dataframe
categories_df_all = pd.DataFrame()

# Loop through the index_list
for i in range(0, len(index_list)-1):
    transaction_names = unique_transactions[index_list[i]:index_list[i+1]]
    transaction_names = ','.join(transaction_names)

    categories_df = categorize_transactions(transaction_names, llm)
    categories_df_all = pd.concat([categories_df_all, categories_df], ignore_index=True)
# Out:
# ['Of course! Here are the appropriate categories for each of the expenses you listed:', '', '1. Rent - Housing', '2. Electricity (EVN) - Utilities', '3. Water - Utilities', '4. Internet (Viettel) - Technology', '5. Phone bill - Communication', '6. Spotify Premium - Entertainment', '7. Netflix - Entertainment', '8. Gym membership - Fitness', '9. English course - Education', '10. Monthly Salary - Income', '11. Freelance Project - Work', '12. Transportation (Grab, Gas) - Transportation', '13. Shopping (Shopee/Clothes) - Shopping', '14. Healthcare - Health', '15. Additional courses - Education', '16. Consulting - Work', '17. Skincare & Cosmetics - Beauty', '18. Food & Drinks (restaurants, cafes) - Food', '', 'I hope this helps! Let me know if you have any other questions.']

# %%
categories_df_all
# Out:
#                               Transaction vs category  \
# 0   Of course! Here are the appropriate categories...
# 1
# 2                                   1. Rent - Housing
# 3                    2. Electricity (EVN) - Utilities
# 4                                3. Water - Utilities
# 5                  4. Internet (Viettel) - Technology
# 6                       5. Phone bill - Communication
# 7                  6. Spotify Premium - Entertainment
# 8                          7. Netflix - Entertainment
# 9                         8. Gym membership - Fitness
# 10                      9. English course - Education
# 11                        10. Monthly Salary - Income
# 12                       11. Freelance Project - Work
# 13    12. Transportation (Grab, Gas) - Transportation
# 14           13. Shopping (Shopee/Clothes) - Shopping
# 15                            14. Healthcare - Health
# 16                 15. Additional courses - Education
# 17                              16. Consulting - Work
# 18                  17. Skincare & Cosmetics - Beauty
# 19      18. Food & Drinks (restaurants, cafes) - Food
# 20
# 21  I hope this helps! Let me know if you have any...
#
#                                           Transaction        Category
# 0   Of course! Here are the appropriate categories...            None
# 1                                                                None
# 2                                             1. Rent         Housing
# 3                                2. Electricity (EVN)       Utilities
# 4                                            3. Water       Utilities
# 5                               4. Internet (Viettel)      Technology
# 6                                       5. Phone bill   Communication
# 7                                  6. Spotify Premium   Entertainment
# 8                                          7. Netflix   Entertainment
# 9                                   8. Gym membership         Fitness
# 10                                  9. English course       Education
# 11                                 10. Monthly Salary          Income
# 12                              11. Freelance Project            Work
# 13                     12. Transportation (Grab, Gas)  Transportation
# 14                      13. Shopping (Shopee/Clothes)        Shopping
# 15                                     14. Healthcare          Health
# 16                             15. Additional courses       Education
# 17                                     16. Consulting            Work
# 18                           17. Skincare & Cosmetics          Beauty
# 19             18. Food & Drinks (restaurants, cafes)            Food
# 20                                                               None
# 21  I hope this helps! Let me know if you have any...            None

# %%
unique_categories = categories_df_all["Category"].unique()
unique_categories
# Out:
# array([None, 'Housing', 'Utilities', 'Technology', 'Communication',
#        'Entertainment', 'Fitness', 'Education', 'Income', 'Work',
#        'Transportation', 'Shopping', 'Health', 'Beauty', 'Food'],
#       dtype=object)

# %%
# Drop NA values
categories_df_all = categories_df_all.dropna()

# %%
# xoá numbering ở đầu như "1. ", "12) ", " 003. "
pat = r'^\s*\d+[\.\)]\s*'

for col in ['Transaction', 'Transaction vs category']:
    categories_df_all.loc[:, col] = (
        categories_df_all[col].astype(str)
        .str.replace(pat, '', regex=True)
        .str.strip(' "\'')              # bỏ ngoặc kép thừa
    )

categories_df_all
# Out:
#                         Transaction vs category  \
# 2                                Rent - Housing
# 3                 Electricity (EVN) - Utilities
# 4                             Water - Utilities
# 5               Internet (Viettel) - Technology
# 6                    Phone bill - Communication
# 7               Spotify Premium - Entertainment
# 8                       Netflix - Entertainment
# 9                      Gym membership - Fitness
# 10                   English course - Education
# 11                      Monthly Salary - Income
# 12                     Freelance Project - Work
# 13  Transportation (Grab, Gas) - Transportation
# 14         Shopping (Shopee/Clothes) - Shopping
# 15                          Healthcare - Health
# 16               Additional courses - Education
# 17                            Consulting - Work
# 18                Skincare & Cosmetics - Beauty
# 19    Food & Drinks (restaurants, cafes) - Food
#
#                            Transaction        Category
# 2                                 Rent         Housing
# 3                    Electricity (EVN)       Utilities
# 4                                Water       Utilities
# 5                   Internet (Viettel)      Technology
# 6                           Phone bill   Communication
# 7                      Spotify Premium   Entertainment
# 8                              Netflix   Entertainment
# 9                       Gym membership         Fitness
# 10                      English course       Education
# 11                      Monthly Salary          Income
# 12                   Freelance Project            Work
# 13          Transportation (Grab, Gas)  Transportation
# 14           Shopping (Shopee/Clothes)        Shopping
# 15                          Healthcare          Health
# 16                  Additional courses       Education
# 17                          Consulting            Work
# 18                Skincare & Cosmetics          Beauty
# 19  Food & Drinks (restaurants, cafes)            Food

# %%
# Merge the categories_df_all with the transactions_2023_2024.csv dataframe (df)
df = pd.read_csv("transactions_2023_2024.csv")
df.loc[df['Name / Description'].str.contains("Spotify"), 'Name / Description'] = "Spotify Ab By Adyen"
df = pd.merge(df, categories_df_all, left_on='Name / Description', right_on='Transaction', how='left')
df
# Out:
#            Date                  Name / Description Expense/Income  \
# 0    2023-01-05                                Rent        Expense
# 1    2023-01-05                   Electricity (EVN)        Expense
# 2    2023-01-05                               Water        Expense
# 3    2023-01-05                  Internet (Viettel)        Expense
# 4    2023-01-05                          Phone bill        Expense
# ..          ...                                 ...            ...
# 322  2024-12-01                      Monthly Salary         Income
# 323  2024-12-20           Shopping (Shopee/Clothes)        Expense
# 324  2024-12-16  Food & Drinks (restaurants, cafes)        Expense
# 325  2024-12-13           Shopping (Shopee/Clothes)        Expense
# 326  2024-12-27           Shopping (Shopee/Clothes)        Expense
#
#     Amount (VND)                    Transaction vs category  \
# 0      6,000,000                             Rent - Housing
# 1        500,000              Electricity (EVN) - Utilities
# 2        200,000                          Water - Utilities
# 3        250,000            Internet (Viettel) - Technology
# 4        150,000                 Phone bill - Communication
# ..           ...                                        ...
# 322   21,765,767                    Monthly Salary - Income
# 323      215,527       Shopping (Shopee/Clothes) - Shopping
# 324      204,343  Food & Drinks (restaurants, cafes) - Food
# 325      288,558       Shopping (Shopee/Clothes) - Shopping
# 326      975,839       Shopping (Shopee/Clothes) - Shopping
#
#                             Transaction       Category
# 0                                  Rent        Housing
# 1                     Electricity (EVN)      Utilities
# 2                                 Water      Utilities
# 3                    Internet (Viettel)     Technology
# 4                            Phone bill  Communication
# ..                                  ...            ...
# 322                      Monthly Salary         Income
# 323           Shopping (Shopee/Clothes)       Shopping
# 324  Food & Drinks (restaurants, cafes)           Food
# 325           Shopping (Shopee/Clothes)       Shopping
# 326           Shopping (Shopee/Clothes)       Shopping
#
# [327 rows x 7 columns]

# %%
df.to_csv("transactions_2023_2024_categorized.csv", index=False)
